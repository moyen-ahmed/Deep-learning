# %% [markdown]
# <a href="https://colab.research.google.com/github/moyen-ahmed/Deep-learning/blob/main/cse4654.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2f2d2bdb-2730-4b97-868c-210e1c84e262" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f2d2bdb-2730-4b97-868c-210e1c84e262">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile, os
zip_path = "/content/bipartite.zip"   # change if your zip has a different name
extract_to = "/content/atome_whisper"

os.makedirs(extract_to, exist_ok=True)

with zipfile.ZipFile(zip_path, "r") as z:
    z.extractall(extract_to)

print("Extracted to:", extract_to)
# Out:
# Extracted to: /content/atome_whisper

# %%
# %cd /content/adtome/
# !pwd
# !ls
# !ls
# Out:
# [Errno 2] No such file or directory: '/content/adtome/'
# /content
# /content
# atome_whisper  bipartite.zip  sample_data
# atome_whisper  bipartite.zip  sample_data

# %%
# %cd /content/atome_whisper/atome_whisper
# !pwd
# !ls
# !ls
# Out:
# /content/atome_whisper/atome_whisper
# /content/atome_whisper/atome_whisper
# atome.py	   merge_map.png	readthisifnew.txt  run_experiment.py
# evaluate.py	   pareto.png		report.md	   visualize.py
# implement.md	   per_layer_stats.csv	requirements.txt   whisper_hooks.py
# layer_heatmap.png  __pycache__		results.csv
# atome.py	   merge_map.png	readthisifnew.txt  run_experiment.py
# evaluate.py	   pareto.png		report.md	   visualize.py
# implement.md	   per_layer_stats.csv	requirements.txt   whisper_hooks.py
# layer_heatmap.png  __pycache__		results.csv

# %%
# !python run_experiment.py
# Out:
# Loading Whisper large-v3 (fp16)...
# config.json: 1.27kB [00:00, 4.17MB/s]
# ...
# model.safetensors: 100% 3.09G/3.09G [00:32<00:00, 96.1MB/s]
# Loading weights: 100% 1259/1259 [00:01<00:00, 782.47it/s, Materializing param=model.encoder.layers.31.self_attn_layer_norm.weight]
# generation_config.json: 3.90kB [00:00, 16.0MB/s]
# preprocessor_config.json: 100% 340/340 [00:00<00:00, 1.93MB/s]
# tokenizer_config.json: 283kB [00:00, 254MB/s]
# vocab.json: 1.04MB [00:00, 40.7MB/s]
# tokenizer.json: 2.48MB [00:00, 166MB/s]
# merges.txt: 494kB [00:00, 110MB/s]
# normalizer.json: 52.7kB [00:00, 110MB/s]
# added_tokens.json: 34.6kB [00:00, 100MB/s]
# special_tokens_map.json: 2.07kB [00:00, 9.70MB/s]
# VRAM after model load: 3.09 GB  (expected ~3 GB for fp16)
#
# ...
# SINGLE-SAMPLE COMPARISON
# ...
# Loading LibriSpeech dummy (clean/validation)...
# README.md: 100% 520/520 [00:00<00:00, 3.40MB/s]
# clean/validation-00000-of-00001.parquet: 100% 9.19M/9.19M [00:00<00:00, 22.4MB/s]
# ...

# %%
pip install jiwer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 52.7 MB/s eta 0:00:00
# ...

# %%
# !python evaluate.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Both `max_new_tokens` (=444) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=444) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=444) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...
