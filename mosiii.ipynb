# %% [markdown]
# <a href="https://colab.research.google.com/github/moyen-ahmed/Deep-learning/blob/main/mosiii.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-396536ea-c826-41f0-8d4f-3755ad3f103c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-396536ea-c826-41f0-8d4f-3755ad3f103c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile, os

zip_path = "/content/SpeachLLM_CSE_465-master.zip"   # change if your zip has a different name
extract_to = "/content"

os.makedirs(extract_to, exist_ok=True)

with zipfile.ZipFile(zip_path, "r") as z:
    z.extractall(extract_to)

print("Extracted to:", extract_to)
# Out:
# Extracted to: /content

# %%
# %cd /content/SpeachLLM_CSE_465-master.zip/
# !pwd
# !ls
# !ls
# Out:
# [Errno 20] Not a directory: '/content/SpeachLLM_CSE_465-master.zip/'
# /content
# /content
# sample_data  SpeachLLM_CSE_465-master  SpeachLLM_CSE_465-master.zip
# sample_data  SpeachLLM_CSE_465-master  SpeachLLM_CSE_465-master.zip

# %%
# %cd /content/SpeachLLM_CSE_465-master
# !pwd
# !ls
# Out:
# /content/SpeachLLM_CSE_465-master
# /content/SpeachLLM_CSE_465-master
# atome.py		      moshi_hooks.py	   results.csv
# bipartite_tome_whisper.ipynb  per_layer_stats.csv  run_experiment.py
# evaluate_moshi.py	      readthisifnew.txt    run_moshi_experiment.py
# evaluate.py		      report.md		   visualize.py
# implement.md		      requirements.txt	   whisper_hooks.py

# %%
# !python run_moshi_experiment.py
# Out:
# Using device: cuda
# Using dtype : torch.float16
# Loading LibriSpeech dummy split...
# README.md: 100% 520/520 [00:00<00:00, 1.68MB/s]
# clean/validation-00000-of-00001.parquet: 100% 9.19M/9.19M [00:00<00:00, 13.1MB/s]
# Generating validation split: 100% 73/73 [00:00<00:00, 1236.12 examples/s]
# [MoshiAToMeHook] Installed hooks on layers: [2, 5, 8, 11]
# [Layer 2] 128 -> 124 (removed 4)
# [Layer 5] 124 -> 120 (removed 4)
# [Layer 8] 120 -> 116 (removed 4)
# [Layer 11] 116 -> 112 (removed 4)
#
# ...
# MOSHI-STYLE TOKEN MERGING EXPERIMENT (LIBRISPEECH DUMMY)
# ...
# Reference text         : MISTER QUILTER IS THE APOSTLE OF THE MIDDLE CLASSES AND WE ARE GLAD TO WELCOME HIS GOSPEL
# Baseline final length  : 128
# Merged final length    : 112
# Reduction              : 12.50%
# Baseline time          : 0.002072 s
# Merged time            : 0.938031 s
# Speedup                : 0.002x
# Shared-prefix cosine   : 1.000000
#
# Per-layer merge info:
#   Layer  2: 128 -> 124 (removed 4)
# ...

# %%
# !python evaluate_moshi.py
# Out:
# Using device: cuda
# Using dtype : torch.float16
# Loading LibriSpeech dummy split...
# Loaded 20 samples.
#
# Evaluating r=0 ...
#   reduction=0.00%  merged_time=0.001915s  speedup=4.557x  shared_prefix_cos=1.000000
#
# Evaluating r=2 ...
#   reduction=6.25%  merged_time=0.013811s  speedup=0.134x  shared_prefix_cos=1.000000
#
# Evaluating r=4 ...
#   reduction=12.50%  merged_time=0.006405s  speedup=0.310x  shared_prefix_cos=1.000000
#
# Evaluating r=6 ...
#   reduction=18.75%  merged_time=0.006425s  speedup=0.300x  shared_prefix_cos=1.000000
#
# Evaluating r=8 ...
#   reduction=25.00%  merged_time=0.008939s  speedup=0.319x  shared_prefix_cos=1.000000
#
# Saved:
#   moshi_results.csv
#   moshi_per_layer_stats.csv
#
# Done.

# %%
# !python evaluate_moshi.py
# Out:
# Using device: cuda
# Using dtype : torch.float16
# Loading LibriSpeech dummy split...
# ...
# Loaded 30 samples.
#
# Evaluating r=0 ...
#   reduction=0.00%  merged_time=0.004309s  speedup=1.011x  shared_prefix_cos=1.000000
#
# Evaluating r=4 ...
#   reduction=4.69%  merged_time=0.012058s  speedup=0.291x  shared_prefix_cos=0.999999
#
# Evaluating r=8 ...
#   reduction=9.38%  merged_time=0.012590s  speedup=0.298x  shared_prefix_cos=0.999999
#
# Evaluating r=12 ...
#   reduction=14.06%  merged_time=0.011557s  speedup=0.294x  shared_prefix_cos=0.999999
#
# Evaluating r=16 ...
#   reduction=18.75%  merged_time=0.013656s  speedup=0.321x  shared_prefix_cos=0.999999
#
# Saved:
#   moshi_results.csv
#   moshi_per_layer_stats.csv
#
# Done.

# %%
# !python evaluate_moshi.py
# Out:
# Using device: cuda
# Using dtype : torch.float16
# Loading LibriSpeech dummy split...
# Loaded 30 samples.
#
# Evaluating r=0 ...
#   reduction=0.00%  merged_time=0.006647s  speedup=1.011x  shared_prefix_cos=1.000000
#
# Evaluating r=8 ...
#   reduction=4.17%  merged_time=0.008643s  speedup=0.501x  shared_prefix_cos=0.999999
#
# Evaluating r=16 ...
#   reduction=8.33%  merged_time=0.008770s  speedup=0.501x  shared_prefix_cos=0.999999
#
# Evaluating r=24 ...
#   reduction=12.50%  merged_time=0.008903s  speedup=0.490x  shared_prefix_cos=0.999999
#
# Evaluating r=32 ...
#   reduction=16.67%  merged_time=0.008743s  speedup=0.507x  shared_prefix_cos=0.999999
#
# Saved:
#   moshi_results.csv
#   moshi_per_layer_stats.csv
#
# Done.

# %%
# !python evaluate_moshi.py
# Out:
# Using device: cuda
# Using dtype : torch.float16
# Loading LibriSpeech dummy split...
# ...
# Loaded 30 samples.
#
# Evaluating r=0 ...
#   reduction=0.00%  merged_time=0.006607s  speedup=1.022x  shared_prefix_cos=1.000000  shared_prefix_mse=0.00000000
#
# Evaluating r=8 ...
#   reduction=4.17%  merged_time=0.008689s  speedup=0.526x  shared_prefix_cos=0.999999  shared_prefix_mse=0.00000152
#
# Evaluating r=16 ...
#   reduction=8.33%  merged_time=0.008272s  speedup=0.507x  shared_prefix_cos=0.999999  shared_prefix_mse=0.00000154
#
# Evaluating r=24 ...
#   reduction=12.50%  merged_time=0.008675s  speedup=0.521x  shared_prefix_cos=0.999999  shared_prefix_mse=0.00000153
#
# Evaluating r=32 ...
#   reduction=16.67%  merged_time=0.008463s  speedup=0.496x  shared_prefix_cos=0.999999  shared_prefix_mse=0.00000152
#
# Saved:
#   moshi_results.csv
#   moshi_per_layer_stats.csv
#   moshi_per_sample_results.csv
#
# Done.

# %%
# !python evaluate_moshi_manual.py
# Out:
# Using device: cuda
# Using dtype : torch.float16
# Loading LibriSpeech dummy split...
# ...
# Loaded 30 samples.
#
# Evaluating r=0 ...
#   reduction=0.00%  merged_time=0.006561s  speedup=1.012x  shared_prefix_cos=1.000000  shared_prefix_mse=0.00000000
#
# Evaluating r=8 ...
#   reduction=4.17%  merged_time=0.008977s  speedup=0.503x  shared_prefix_cos=0.999999  shared_prefix_mse=0.00000152
#
# Evaluating r=16 ...
#   reduction=8.33%  merged_time=0.008530s  speedup=0.508x  shared_prefix_cos=0.999999  shared_prefix_mse=0.00000154
#
# Evaluating r=24 ...
#   reduction=12.50%  merged_time=0.008441s  speedup=0.515x  shared_prefix_cos=0.999999  shared_prefix_mse=0.00000153
#
# Evaluating r=32 ...
#   reduction=16.67%  merged_time=0.009179s  speedup=0.523x  shared_prefix_cos=0.999999  shared_prefix_mse=0.00000152
#
# Saved:
#   moshi_manual_results.csv
#   moshi_manual_per_layer_stats.csv
#   moshi_manual_per_sample_results.csv
#
# Done.

# %%
# !python evaluate_moshi_adjacent.py
# Out:
# Using device: cuda
# Using dtype : torch.float16
# Loading LibriSpeech dummy split...
# ...
# Loaded 30 samples.
#
# Evaluating r=0 ...
#   reduction=0.00%  merged_time=0.006515s  speedup=1.021x  shared_prefix_cos=1.000000  shared_prefix_mse=0.00000000
#
# Evaluating r=8 ...
#   reduction=4.17%  merged_time=0.097447s  speedup=0.065x  shared_prefix_cos=0.999999  shared_prefix_mse=0.00000149
#
# Evaluating r=16 ...
#   reduction=8.33%  merged_time=0.106697s  speedup=0.084x  shared_prefix_cos=0.999999  shared_prefix_mse=0.00000154
#
# Evaluating r=24 ...
#   reduction=12.50%  merged_time=0.102501s  speedup=0.089x  shared_prefix_cos=0.999999  shared_prefix_mse=0.00000154
#
# Evaluating r=32 ...
#   reduction=16.67%  merged_time=0.091676s  speedup=0.098x  shared_prefix_cos=0.999999  shared_prefix_mse=0.00000152
#
# Saved:
#   moshi_adjacent_results.csv
#   moshi_adjacent_per_layer_stats.csv
#   moshi_adjacent_per_sample_results.csv
#
# Done.

# %%
# !python evaluate_moshi_adjacent_fast.py
# Out:
# Using device: cuda
# Using dtype : torch.float16
# Loading LibriSpeech dummy split...
# ...
# Loaded 30 samples.
#
# Evaluating r=0 ...
#   reduction=0.00%  merged_time=0.005626s  speedup=1.009x  shared_prefix_cos=1.000000  shared_prefix_mse=0.00000000
#
# Evaluating r=8 ...
#   reduction=4.17%  merged_time=0.009808s  speedup=0.449x  shared_prefix_cos=0.999999  shared_prefix_mse=0.00000149
#
# Evaluating r=16 ...
#   reduction=8.33%  merged_time=0.009721s  speedup=0.454x  shared_prefix_cos=0.999999  shared_prefix_mse=0.00000154
#
# Evaluating r=24 ...
#   reduction=12.50%  merged_time=0.014054s  speedup=0.449x  shared_prefix_cos=0.999999  shared_prefix_mse=0.00000154
#
# Evaluating r=32 ...
#   reduction=16.67%  merged_time=0.012807s  speedup=0.457x  shared_prefix_cos=0.999999  shared_prefix_mse=0.00000152
#
# Saved:
#   moshi_adjacent_fast_results.csv
#   moshi_adjacent_fast_per_layer_stats.csv
#   moshi_adjacent_fast_per_sample_results.csv
#
# Done.

# %%
# !python compare_visualize.py
# Out:
# ...
# WHISPER SUMMARY
# ...
#   r  reduction_pct  avg_time_s  speedup    wer  peak_vram_gb
#   0           0.00       0.804 1.000000 0.1470         3.365
#  25          16.67       0.780 1.030769 0.1426         3.360
#  50          33.33       0.778 1.033419 0.1374         3.319
#  75          50.00       0.751 1.070573 0.1365         3.270
# 100          66.67       0.741 1.085020 0.1383         3.229
# 125          83.33       0.757 1.062087 0.1557         3.180
# 135          90.00       0.722 1.113573 0.1939         3.156
#
# ...
# MOSHI MANUAL BIPARTITE SUMMARY
# ...
#  r  reduction_pct   time_s  speedup  avg_shared_prefix_cosine  avg_shared_prefix_mse
#  0         0.0000 0.006561 1.011793                  1.000000               0.000000
#  8         4.1667 0.008977 0.502918                  0.999999               0.000002
# 16         8.3333 0.008530 0.507539                  0.999999               0.000002
# 24        12.5000 0.008441 0.514745                  0.999999               0.000002
# ...
