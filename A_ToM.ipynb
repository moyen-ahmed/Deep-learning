# %% [markdown]
# <a href="https://colab.research.google.com/github/moyen-ahmed/Deep-learning/blob/main/A_ToM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-05dc4afb-bc2c-4223-b399-3b615847eec8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05dc4afb-bc2c-4223-b399-3b615847eec8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile, os

zip_path = "/content/project update.zip"   # change if your zip has a different name
extract_to = "/content/project"

os.makedirs(extract_to, exist_ok=True)

with zipfile.ZipFile(zip_path, "r") as z:
    z.extractall(extract_to)

print("Extracted to:", extract_to)
# Out:
# Extracted to: /content/project

# %%
# %cd /content/adtome/
# !pwd
# !ls
# !ls
# Out:
# [Errno 2] No such file or directory: '/content/adtome/'
# /content
# /content
# atome_whisper  project	sample_data
# atome_whisper  project	sample_data

# %%
# %cd /content/atome_whisper
# !pwd
# !ls
# Out:
# /content/atome_whisper
# /content/atome_whisper
# atome.py	   merge_map.png	readthisifnew.txt  run_experiment.py
# evaluate.py	   pareto.png		report.md	   visualize.py
# implement.md	   per_layer_stats.csv	requirements.txt   whisper_hooks.py
# layer_heatmap.png  __pycache__		results.csv

# %%
# !python run_experiment.py
# Out:
# Loading Whisper large-v3 (fp16)...
# config.json: 1.27kB [00:00, 4.15MB/s]
# ...
# model.safetensors: 100% 3.09G/3.09G [00:24<00:00, 124MB/s]
# Loading weights: 100% 1259/1259 [00:01<00:00, 791.02it/s, Materializing param=model.encoder.layers.31.self_attn_layer_norm.weight]
# generation_config.json: 3.90kB [00:00, 16.6MB/s]
# preprocessor_config.json: 100% 340/340 [00:00<00:00, 1.56MB/s]
# tokenizer_config.json: 283kB [00:00, 298MB/s]
# vocab.json: 1.04MB [00:00, 61.2MB/s]
# tokenizer.json: 2.48MB [00:00, 107MB/s]
# merges.txt: 494kB [00:00, 78.2MB/s]
# normalizer.json: 52.7kB [00:00, 72.5MB/s]
# added_tokens.json: 34.6kB [00:00, 65.5MB/s]
# special_tokens_map.json: 2.07kB [00:00, 7.92MB/s]
# VRAM after model load: 3.09 GB  (expected ~3 GB for fp16)
#
# ...
# SINGLE-SAMPLE COMPARISON
# ...
# Loading LibriSpeech dummy (clean/validation)...
# README.md: 100% 520/520 [00:00<00:00, 2.63MB/s]
# clean/validation-00000-of-00001.parquet: 100% 9.19M/9.19M [00:00<00:00, 22.3MB/s]
# ...

# %%
pip install jiwer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 72.6 MB/s eta 0:00:00
# ...

# %%
# !python evaluate.py --dummy
# Out:
# Loading Whisper large-v3 (fp16)...
# ...
# Loading weights: 100% 1259/1259 [00:01<00:00, 680.63it/s, Materializing param=model.encoder.layers.31.self_attn_layer_norm.weight]
# VRAM after load: 3.09 GB
# Loading LibriSpeech dummy split (development mode)...
#
# Evaluating threshold=1.00 ...
# Both `max_new_tokens` (=444) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...

# %%
# !python visualize.py --all
# Out:
# Loading model for merge-map visualization...
# ...
# Loading weights: 100% 1259/1259 [00:01<00:00, 769.71it/s, Materializing param=model.encoder.layers.31.self_attn_layer_norm.weight]
# Both `max_new_tokens` (=444) and `max_length`(=448) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# A custom logits processor of type <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> has been passed to `.generate()`, but it was also created in `.generate()`, given its parameterization. The custom <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> will take precedence. Please check the docstring of <class 'transformers.generation.logits_process.SuppressTokensLogitsProcessor'> to see related `.generate()` flags.
# ...
